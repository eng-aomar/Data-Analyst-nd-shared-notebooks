# %% [markdown]
# # Requests Library:
# ----
# Ref:
# * https://realpython.com/python-requests/#getting-started-with-pythons-requests-library
#
# * https://requests.readthedocs.io/en/latest/
# * https://www.w3schools.com/python/module_requests.asp

# %% [markdown]
# >[Requests Library:](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=g2CDY2fh47XY)
#
# >>[The Respons](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=CSGjA_6K0rbS)
#
# >>[2XX Success Codes](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=mxman7OV1kps)
#
# >>[Response Content](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=_JJtO3Yy5yab)
#
# >>>[Binary Response Content](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=CYAtMwmw6wzY)
#
# >>>[Raw Response Content](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=qAb0Xgkn7C9B)
#
# >>>[JSON Response Content](#updateTitle=true&folderId=1k1W4TNmIbpcTuR73crJ_szehJJWw95RK&scrollTo=vP4PSa8-69nq)

# %%
import requests
requests.get("https://api.github.com")
# Out:
# <Response [200]>

# %% [markdown]
# ## The Respons
#
#
# ---
# italicized text
# ![image.png](data:image/png;base64,...)
#
# ----
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2XX Success Codes
# ----
# ![image.png](data:image/png;base64,...)

# %%
response = requests.get("https://api.github.com")
response
# Out:
# <Response [200]>

# %% [markdown]
# If you invoke `.raise_for_status()`, then Requests will raise an `HTTPError` for status codes between **400** and **600**. If the status code indicates a successful request, then the program will proceed without raising that exception.

# %%
print(response.raise_for_status())
# Out:
# None

# %% [markdown]
# **Content**
# The response of a `GET` request often has some valuable information, known as a `payload`, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use .content:

# %% [markdown]
# ## Response Content

# %%
response.content
# Out:
# b'{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://ap
# ...

# %% [markdown]
# ### Binary Response Content

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# While `.content` gives you access to the raw bytes of the response payload, you’ll often want to convert them into a string using a character encoding such as **`UTF-8`**. response will do that for you when you access .text:

# %%
response.text
# Out:
# '{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://api
# ...

# %%
response.text.split(" ")
# Out:
# ['{\n',
#  '',
#  '"current_user_url":',
#  '"https://api.github.com/user",\n',
#  '',
#  '"current_user_authorizations_html_url":',
#  '"https://github.com/settings/connections/applications{/client_id}",\n',
#  '',
#  '"authorizations_url":',
#  '"https://api.github.com/authorizations",\n',
#  '',
#  '"code_search_url":',
#  '"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n',
#  '',
#  '"commit_search_url":',
#  '"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n',
#  '',
#  '"emails_url":',
#  '"https://api.github.com/user/emails",\n',
#  '',
#  '"emojis_url":',
#  '"https://api.github.com/emojis",\n',
#  '',
#  '"events_url":',
#  '"https://api.github.com/events",\n',
#  '',
#  '"feeds_url":',
#  '"https://api.github.com/feeds",\n',
#  '',
#  '"followers_url":',
#  '"https://api.github.com/user/followers",\n',
#  '',
#  '"following_url":',
#  '"https://api.github.com/user/following{/target}",\n',
#  '',
#  '"gists_url":',
# ...

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# If you take a look at the response, then you’ll see that it’s actually serialized `JSON` content. To get a dictionary, you could take the str that you retrieved from .text and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %% [markdown]
# ###Raw Response Content

# %%
response.raw

# %%
response.raw.read(0)
# Out:
# b''

# %% [markdown]
# ###JSON Response Content

# %%
data = response.json()

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# The type of the return value of `.json()` is a dictionary, so you can access values in the object by key:

# %%
response_dict = response.json()

# %%
response_dict["emojis_url"]
# Out:
# 'https://api.github.com/emojis'
